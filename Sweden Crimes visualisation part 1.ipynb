# %%
import numpy as np#importing dataset
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv('Desktop\ML\datasets_851_1557_reported.csv')
df
# Out:
#     Year  crimes.total  crimes.penal.code  crimes.person  murder  assault  \
# 0   1950          2784               2306            120       1      105
# 1   1951          3284               2754            125       1      109
# 2   1952          3160               2608            119       1      104
# 3   1953          2909               2689            119       1      105
# 4   1954          3028               2791            126       1      107
# ..   ...           ...                ...            ...     ...      ...
# 61  2011         14988              12267           1005       2      947
# 62  2012         14734              12148            974       2      914
# 63  2013         14603              12072            896       3      837
# 64  2014         14890              12305            923       3      859
# 65  2015         15342              12803            932       3      868
#
#     sexual.offenses  rape  stealing.general  burglary  ...  vehicle.theft  \
# ...

# %%
df.describe()
# Out:
#               Year  crimes.total  crimes.penal.code  crimes.person     murder  \
# count    66.000000     66.000000          66.000000      66.000000  66.000000
# mean   1982.500000  10084.257576        8695.181818     451.287879   1.757576
# std      19.196354   4223.893287        3582.148938     295.041002   0.724529
# min    1950.000000   2784.000000        2306.000000     119.000000   1.000000
# 25%    1966.250000   6152.500000        5336.000000     185.250000   1.000000
# 50%    1982.500000  11654.000000        9637.000000     370.500000   2.000000
# 75%    1998.750000  13663.750000       12002.500000     690.500000   2.000000
# max    2015.000000  15342.000000       12803.000000    1005.000000   4.000000
#
#           assault  sexual.offenses       rape  stealing.general     burglary  \
# count   66.000000        66.000000  66.000000         66.000000    66.000000
# mean   423.106061        75.318182  20.045455       5580.545455  1240.681818
# ...

# %%
#checking the null values
missing_val_count_by_column = (df.isnull().sum())
print(missing_val_count_by_column[missing_val_count_by_column>0])
# Out:
# house.theft             15
# vehicle.theft            7
# out.of.vehicle.theft    15
# shop.theft              15
# narcotics                4
# dtype: int64

# %%
#removing the null columns
df = df.dropna(axis = 0)
df.head()
# Out:
#     Year  crimes.total  crimes.penal.code  crimes.person  murder  assault  \
# 15  1965          5801               5090            167       3      151
# 16  1966          6063               5263            184       3      166
# 17  1967          6421               5555            189       2      173
# 18  1968          7166               6242            228       1      212
# 19  1969          7671               6036            241       1      223
#
#     sexual.offenses  rape  stealing.general  burglary  ...  vehicle.theft  \
# 15               51     8              3694      1042  ...          397.0
# 16               48     8              3736      1031  ...          350.0
# 17               49     8              3939      1086  ...          384.0
# 18               47     8              4240      1232  ...          396.0
# 19               42     8              4142      1131  ...          384.0
#
#     out.of.vehicle.theft  shop.theft  robbery  fraud  criminal.damage  \
# ...

# %% [markdown]
# ### Histogram of the entire df

# %%
df.hist(bins=50,figsize=(20,15))
plt.show()

# %% [markdown]
# ### Population of Sweden

# %%
plt.scatter(df['Year'],df['population'])
plt.xlabel('Year')
plt.ylabel('Population')
plt.title('POpulation Growth in Sweden')
plt.grid()
plt.show()

# %% [markdown]
# ### Lets see a 3d scatter plot of Total Crime over population…

# %%
from mpl_toolkits import mplot3d

# %%
fig = plt.figure()
ax = plt.axes(projection='3d')
ax.scatter3D(df['Year'], df['population'], df['crimes.total'], color='Green')
plt.title('3-D plot of total crimes over population from 1965 to 2010',fontsize=15)
plt.show()

# %%
#for better visualisation
#Wireframes

fig = plt.figure()
ax = plt.axes(projection='3d')
ax.plot_wireframe(df['Year'], df['population'], df[['crimes.total']], color='black')
ax.set_title('wireframe')
plt.show()
#surface plot
ax = plt.axes(projection='3d')
ax.plot_surface(df['Year'], df['population'], df[['crimes.total']],
                cmap='viridis', edgecolor='none')
ax.set_title('surface plot')
plt.show()

# %% [markdown]
# ### Visualising all the crimes together

# %%
import mplcursors
x = df['Year']

plt.figure(figsize=(12,10))
plt.plot(x,df['murder'],label='Murder')
plt.plot(x,df['assault'],label='Assault')
plt.plot(x,df['crimes.total'],label='Total Crimes',c='black')
plt.plot(x,df['sexual.offenses'],label='Sexual offense')
plt.plot(x,df['burglary'],label='Burglary')
plt.plot(x,df['stealing.general'],label='General stealing')
plt.plot(x,df['vehicle.theft'],label='Vechicle theft')
plt.plot(x,df['robbery'],label='Robbery')
plt.plot(x,df['fraud'],label='Fraud')
plt.plot(x,df['criminal.damage'],label='Criminal damage')
plt.plot(x,df['narcotics'],label='Narcotics')
plt.plot(x,df['drunk.driving'],label='Drink and drive')
plt.plot(x,df['other.penal.crimes'],label='other theft')
plt.plot(x,df['out.of.vehicle.theft'],label='outside theft')
plt.plot(x,df['crimes.person'],label='No of crimes')
plt.plot(x,df['house.theft'],label='house theft')
plt.plot(x,df['crimes.penal.code'],label='Crimes penal code')
plt.plot(x,df['shop.theft'],label='Shop theft')
plt.grid()
plt.legend(bbox_to_anchor=(1.2,1),loc='upper right')
plt.xlabel('Year')
plt.show()

# %% [markdown]
# ### From this plot we can see that Stealing(gen) is the most reported crimes.

# %% [markdown]
# ### Bar graph

# %%
#bar graph of total crimes in years
import plotly.graph_objects as go
y = df['crimes.total'].values
x = df['Year'].values
plt.bar(x,y)
plt.xlabel('Year')
plt.ylabel('Total crimes')
plt.show()

# %%
plt.figure(figsize=(18,18))
plt.subplot(5,4,1)
#burglary cases 
plt.bar(df['Year'],df['burglary'],color='cyan')
plt.xlabel('year')
plt.ylabel('burglary')
plt.grid()
#shop theft
plt.subplot(5,4,2)
plt.bar(df['Year'],df['shop.theft'],color="yellow")
plt.xlabel('year')
plt.ylabel('Shop theft')
plt.grid()

#house theft 
plt.subplot(5,4,3)
plt.bar(df['Year'],df['house.theft'],color="lightgreen")
plt.xlabel('year')
plt.ylabel('house theft')

plt.grid()
#drink and drive 
plt.subplot(5,4,4)
plt.bar(df['Year'],df['drunk.driving'])
plt.xlabel('year')
plt.ylabel('drink drive')
plt.grid()
#fraud
plt.subplot(5,4,5)
plt.bar(df['Year'],df['fraud'],color="brown")
plt.xlabel('year')
plt.ylabel('fraud')
plt.grid()
#vehicle theft 
plt.subplot(5,4,6)
plt.bar(df['Year'],df['vehicle.theft'],color="pink")
plt.xlabel('year')
plt.ylabel('vehicle theft')
plt.grid()
#out of vehicle theft 
plt.subplot(5,4,7)
plt.bar(df['Year'],df['out.of.vehicle.theft'],color="violet")
plt.xlabel('year')
plt.ylabel('out of vehicle theft')
plt.grid()

#rape 
plt.subplot(5,4,8)
plt.bar(df['Year'],df['rape'],color="orange")
plt.xlabel('year')
plt.ylabel('rape')
plt.grid()

#assault 
plt.subplot(5,4,9)
plt.bar(df['Year'],df['assault'],color="indigo")
plt.xlabel('year')
plt.ylabel('assault')

plt.grid()
#murder 
plt.subplot(5,4,10)
plt.bar(df['Year'],df['murder'],color ="darkgreen")
plt.xlabel('year')
plt.ylabel('murder')
plt.grid()

#narcotics
plt.subplot(5,4,11)
plt.bar(df['Year'],df['narcotics'],color='magenta')
plt.xlabel('year')
plt.ylabel('narcotics')
plt.grid()

#sexual offenses
plt.subplot(5,4,12)
plt.bar(df['Year'],df['sexual.offenses'],color="burlywood")
plt.xlabel('year')
plt.ylabel('sexual offense')
plt.grid()

#criminal damage 
plt.subplot(5,4,13)
plt.bar(df['Year'],df['criminal.damage'],color='chartreuse')
plt.xlabel('year')
plt.ylabel('house theft')

plt.grid()
#stealing general 
plt.subplot(5,4,14)
plt.bar(df['Year'],df['stealing.general'],color="olive")
plt.xlabel('year')
plt.ylabel('stealing general')

plt.grid()
#other penal crimes
plt.subplot(5,4,15)
plt.bar(df['Year'],df['other.penal.crimes'],color="crimson")

plt.xlabel('year')
plt.ylabel('other penal crimes')

plt.grid()
plt.show()

# %% [markdown]
# ### Voiolin plot of each crime
# A Violin Plot is used to visualise the distribution of the data and its probability density.

# %% [markdown]
# <img style= 'float:left' src='Desktop/Capture.png' />

# %%
import seaborn as sns
plt.figure(figsize=(18,18))
plt.subplot(5,4,1)
sns.violinplot(df['assault'],color='lime')
plt.grid()
plt.subplot(5,4,2)
sns.violinplot(df['rape'],color='pink')
plt.grid()
plt.subplot(5,4,3)
sns.violinplot(df['fraud'],color='indigo')
plt.grid()
plt.subplot(5,4,4)
sns.violinplot(df['narcotics'],color='yellow')
plt.grid()
plt.subplot(5,4,5)
sns.violinplot(df['murder'],color='red')
plt.grid()
plt.subplot(5,4,6)
sns.violinplot(df['drunk.driving'],color='brown')
plt.grid()
plt.subplot(5,4,7)
sns.violinplot(df['sexual.offenses'],color='orange')
plt.grid()
plt.subplot(5,4,8)
sns.violinplot(df['house.theft'],color='green')
plt.grid()
plt.subplot(5,4,9)
sns.violinplot(df['vehicle.theft'],color='cyan')
plt.grid()
plt.subplot(5,4,10)
sns.violinplot(df['out.of.vehicle.theft'],color='lightblue')
plt.grid()
plt.subplot(5,4,11)
sns.violinplot(df['stealing.general'],color='violet')
plt.grid()
plt.subplot(5,4,12)
sns.violinplot(df['burglary'],color='purple')
plt.grid()
plt.subplot(5,4,13)
sns.violinplot(df['shop.theft'],color='crimson')
plt.grid()
plt.subplot(5,4,14)
sns.violinplot(df['robbery'],color='olive')
plt.grid()
plt.show()

# %% [markdown]
# ### The crimes can be divided into 2 types:
#
# 1.Theft Crimes
#
# 2.Crimes other than theft

# %% [markdown]
# ### Theft crimes

# %%
x= df['Year']
y =[0,500,1500,2500,3500,4500,5500,6500,7500]
plt.figure(figsize=(18,4))
plt.subplot(171)
plt.plot(x,df['burglary'],c='r')
plt.grid()
plt.text(1990,7750,"   burglary   ",ha='center',bbox = dict(fc="None"),c="black",size=18,weight='ultralight')
plt.yticks(y)
plt.ylabel('Theft crime reported',fontsize=15)
plt.subplot(172)
plt.plot(x,df['house.theft'],c='y')
plt.text(1990,7750,"house.theft",ha='center',bbox = dict(fc="None"),c="black",size=20,weight='ultralight', backgroundcolor='black')
plt.yticks(y,"")
plt.grid()
plt.subplot(173)
plt.plot(x,df['out.of.vehicle.theft'],c='lightgreen')
plt.grid()
plt.text(1990,7750,"out.of,vehicle.theft",ha='center',bbox = dict(fc="None"),c="black",weight='ultralight',size=12)
plt.yticks(y,"")
plt.subplot(174)
plt.plot(x,df['robbery'],c='darkblue')
plt.grid()
plt.text(1990,7750,"   robbery   ",ha='center',bbox = dict(fc="None"),c="black",size=20,weight='ultralight')
plt.yticks(y,"")
plt.xlabel('Year',fontsize=15)
plt.subplot(175)
plt.plot(x,df['shop.theft'],c='violet')
plt.grid()
plt.text(1990,7750,"shop.theft",ha='center',bbox = dict(fc="None"),c="black",size=22,weight='ultralight')
plt.yticks(y,"")
plt.subplot(176)
plt.plot(x,df['stealing.general'],c='pink')
plt.grid()
plt.text(1990,9150,"stealing.general",ha='center',bbox = dict(fc="None"),c="black",size=14,weight='ultralight')
plt.yticks(y,"")
plt.subplot(177)
plt.plot(x,df['vehicle.theft'])
plt.grid()
plt.text(1990,7750,"vehicle.theft",ha='center',bbox = dict(fc="None"),c="black",size=18,weight='ultralight')
plt.yticks(y,"")

plt.show()

# %% [markdown]
# ### Crimes other than theft

# %%
x=df['Year']
y = [0,500,1000,1500,2000]
plt.figure(figsize=(20,5))
plt.subplot(1,8,1)
plt.plot(x,df['assault'],c='cyan')
plt.text(1990,2070,"   assault   ",ha='center',bbox = dict(fc="None"),c="grey",size=20,weight='ultralight')
plt.yticks(y)
plt.grid()
plt.ylabel('Other Crimes Reported',fontsize=15)
plt.subplot(1,8,2)
plt.plot(x,df['criminal.damage'],c="r")
plt.grid()
plt.text(1990,2345,"criminal.damage",ha='center',bbox = dict(fc="None"),c="grey",size=13,weight='ultralight')
plt.yticks(y,"")
plt.subplot(1,8,3)
plt.plot(x,df['drunk.driving'],c='lightblue')
plt.grid()
plt.text(1990,2070,"drunk.driving",ha='center',bbox = dict(fc="None"),c="grey",size=17,weight='ultralight')
plt.yticks(y,"")
plt.subplot(1,8,4)
plt.plot(x,df['fraud'],c='orange')
plt.text(1990,2085,"  fraud   ",ha='center',bbox = dict(fc="None"),c="grey",size= 26,weight='ultralight')
plt.yticks(y,"")
plt.xlabel('Year',fontsize=15)
plt.grid()
plt.subplot(1,8,5)
plt.plot(x,df['murder'],c='brown')
plt.text(1990,2070,"   murder ",ha ='center',bbox = dict(fc="None"),c="grey",size= 22,weight='ultralight')
plt.yticks(y,"")
plt.grid()
plt.subplot(1,8,6)
plt.plot(x,df['narcotics'],c='pink')
plt.text(1990,2075,"narcotics"   ,ha='center' , bbox=dict(fc='None'),c='grey'  ,   size  =24 , weight='ultralight')
plt.yticks(y,"")
plt.grid()
plt.subplot(1,8,7)
plt.plot(x,df['rape'],c='green')
plt.text(1990,2075,"   rape    ",ha='center' , bbox=dict(fc='None'),c='grey'  ,   size  =25 , weight='ultralight')
plt.yticks(y,"")
plt.grid()
plt.subplot(1,8,8)
plt.plot(x,df['sexual.offenses'])
plt.text(1990,2070,'sexual.offenses',ha='center' , bbox=dict(fc='None'),c='grey'  ,   size  =14 , weight='ultralight')
plt.yticks(y,"")
plt.grid()

# %% [markdown]
# ### From the above graphs we can see that thefts like :
# Assault,criminal.damage,fraud,narcotics,sexual.offenses,drunk.driving are increasing.

# %% [markdown]
# ### Pairplot

# %%
import seaborn as sns
g = sns.pairplot(df, plot_kws={'color':'green'})

# %% [markdown]
# ### Correlation between the features

# %%
#to find correlation between the years and crimes
corr_matrix= df.corr()
corr_matrix['Year'].sort_values(ascending = False)
# Out:
# Year                    1.000000
# crimes.person           0.982497
# assault                 0.981828
# population              0.979033
# criminal.damage         0.965263
# robbery                 0.958692
# crimes.total            0.928397
# sexual.offenses         0.912722
# crimes.penal.code       0.903144
# rape                    0.871042
# other.penal.crimes      0.762467
# narcotics               0.745582
# shop.theft              0.720945
# murder                  0.531833
# stealing.general        0.417623
# fraud                   0.398538
# drunk.driving           0.270600
# house.theft             0.215628
# out.of.vehicle.theft    0.149493
# vehicle.theft          -0.110014
# burglary               -0.410688
# Name: Year, dtype: float64

# %% [markdown]
# ### There is a  very strong positive correlation between
#
#
# 1.Year and crimes.person
#
#
# 2.Year and population
#
# 3.Year and criminal.damage
#
# 4.Year and crimes.total
#
# 5.Assualts and robbery ,etc....
#
# i.e. with inc in year these are also increasing

# %% [markdown]
# ### Correlation of popultaion with the crimes

# %%
#to find correlation between the population and crimes
df_new = df.drop('Year',axis=1)
corr_matrix= df_new.corr()
corr_matrix['population'].sort_values(ascending = False)
# Out:
# population              1.000000
# crimes.person           0.964391
# assault                 0.961196
# sexual.offenses         0.943727
# criminal.damage         0.927605
# rape                    0.913938
# robbery                 0.901771
# crimes.total            0.875447
# crimes.penal.code       0.835563
# other.penal.crimes      0.796891
# narcotics               0.781308
# shop.theft              0.613134
# murder                  0.531794
# fraud                   0.468938
# stealing.general        0.291816
# drunk.driving           0.280294
# house.theft             0.198465
# out.of.vehicle.theft   -0.009728
# vehicle.theft          -0.244123
# burglary               -0.476625
# Name: population, dtype: float64

# %% [markdown]
# ### Heat map to visualise the corr

# %%
#heat map of thefts
import seaborn as sns
sns.set()
pc =df[['shop.theft','vehicle.theft','house.theft', 'burglary','out.of.vehicle.theft','robbery','stealing.general']].corr(method ='pearson')

cols = ['shop.theft','vehicle.theft','house.theft', 'burglary','out.of.vehicle.theft','robbery','stetaling.general']
ax = sns.heatmap(pc, annot=True,
                 yticklabels=cols,
                 xticklabels=cols,
                 annot_kws={'size': 10})

# %%
import seaborn as sns
plt.figure(figsize=(21,21))
sns.heatmap(df.corr(method='pearson'),annot=True, annot_kws={'size': 10})

# %%
### COnsidering last 30 years
a = df.tail(30).reset_index()
plt.plot(a["population"])
plt.xticks(range(0,len(a["population"])), a["Year"], rotation = 90)

plt.show()

# %% [markdown]
# ### Stack plot

# %%
#stack plot
sns.set()
plt.figure(figsize=(15,10))
plt.bar(range(0,len(a['crimes.person'])), a["crimes.person"], label="crimes.person", linewidth=5., color = "green")
plt.bar(range(0,len(a['burglary'])), a["burglary"], label="burglary", linewidth=5., color ="lightblue")
plt.bar(range(0,len(a["out.of.vehicle.theft"])), a["out.of.vehicle.theft"], label="out of vehicle theft", linewidth=5., color ="brown")
plt.bar(range(0,len(a["house.theft"])), a["house.theft"], label="house.theft", linewidth=5., color ="yellow")


plt.plot(a["rape"], linestyle = "-.",label="rape",c="red")

plt.xticks(range(0,len(a["crimes.person"])), a["Year"], rotation = 90)
plt.title("Rapes  and thefts by year", fontsize = 20)
plt.legend(loc="upper right", fontsize=14)
plt.xlabel("Year")

plt.show()

# %% [markdown]
# ### criminal damage

# %%
y= df['criminal.damage']
x= df['Year']

# %%
import seaborn as sns
sns.set()

# %%
plt.plot(x,y)
plt.xlabel('Year')
plt.ylabel('Crminal Damage')
plt.title('Criminal damage over the years')
plt.show()

# %%
plt.hist(y)
plt.xlabel('No  of damage')
plt.ylabel('Ho many times?')
plt.show()

# %%
plt.bar(x,y)
plt.xlabel('Year')
plt.ylabel('Damage caused by criiminals')
plt.show()

# %%
sns.jointplot(x,y,data=df,kind='reg')

# %% [markdown]
# ### Criminal damage over population

# %%
from mpl_toolkits import mplot3d

# %%
fig = plt.figure()
ax = plt.axes(projection='3d')
ax.scatter3D(df['Year'], df['population'], df['criminal.damage'], color='Green')
plt.title('3-D plot of criminal damage over population from 1965 to 2010',fontsize=15)
plt.show()

# %%
fig = plt.figure()
ax = plt.axes(projection='3d')
ax.scatter3D(df['crimes.total'], df['population'], df['criminal.damage'], color='Green')
plt.title('3-D plot of criminal damage over population over the total crimes',fontsize=15)
plt.show()

# %%
sns.kdeplot(df['Year'],df['criminal.damage'])

# %%
sns.kdeplot(df['Year'],df['criminal.damage'],shade=True)

# %%
sns.kdeplot(df['population'],df['criminal.damage'],cbar = True)

# %%
ax =sns.kdeplot(df['crimes.total'],df['criminal.damage'],cmap='Reds',shade=True, shade_lowest=False)
ax =sns.kdeplot(df['crimes.person'],df['criminal.damage'],cmap ='Blues',shade=True, shade_lowest=False)

# %%
corr_matrix= df.corr()
corr_matrix['criminal.damage'].sort_values(ascending = False)
# Out:
# criminal.damage         1.000000
# assault                 0.969945
# crimes.person           0.969074
# Year                    0.965263
# robbery                 0.952022
# population              0.927605
# crimes.total            0.900758
# crimes.penal.code       0.876916
# sexual.offenses         0.870587
# rape                    0.847854
# other.penal.crimes      0.737124
# shop.theft              0.716107
# narcotics               0.703016
# murder                  0.494896
# stealing.general        0.398331
# fraud                   0.334781
# drunk.driving           0.326047
# house.theft             0.186082
# out.of.vehicle.theft    0.160614
# vehicle.theft          -0.099727
# burglary               -0.407009
# Name: criminal.damage, dtype: float64

# %% [markdown]
# ###    The criminal damages are increasing with increase in year ,population,crimes.person,crimes.total

# %%
x = df[['Year','criminal.damage','crimes.total','population']]
sns.heatmap(x.corr(method='pearson'),annot=True, annot_kws={'size': 10})

# %%
ax =sns.boxplot(y,color='red')
ax2 = sns.boxplot(df['crimes.total'],color = 'yellow')
plt.title('Total crimes and Criminal damages')
plt.xlabel('damage and crime')
plt.show()

# %%
x = df['criminal.damage']
sns.distplot(x)
mean = x.mean()
plt.axvline(mean,0,1,color='red')
print('Mean:',mean)
plt.show()
# Out:
# Mean: 1095.3921568627452

# %%
x = df['crimes.total']
sns.distplot(x)
mean = x.mean()
plt.axvline(mean,0,1,color='red')
print('Mean:',mean)
plt.show()
# Out:
# Mean: 11962.0

# %%
plt.figure(figsize=(12,12))
pd.plotting.andrews_curves(df,'criminal.damage')

# %%
plt.figure(figsize=(12,12))
pd.plotting.andrews_curves(df,'crimes.person')

# %%
import plotly.express as px


fig = px.line(df, x="Year", y="crimes.total")

fig.add_scatter(x=df['Year'],y = df['robbery'],mode='lines',name='robbery')

fig.add_scatter(x=df['Year'],y = df['shop.theft'],mode='lines',name='shop theft')

fig.add_scatter(x=df['Year'],y = df['vehicle.theft'],mode='lines',name='vehivle theft')

fig.add_scatter(x=df['Year'],y = df['house.theft'],mode='lines',name='house theft')

fig.add_scatter(x=df['Year'],y = df['stealing.general'],mode='lines',name='stealing general')

fig.add_scatter(x=df['Year'],y = df['fraud'],mode='lines',name='fraud')

fig.add_scatter(x=df['Year'],y = df['rape'],mode='lines',name='rape')

fig.add_scatter(x=df['Year'],y = df['murder'],mode='lines',name='murder')

fig.add_scatter(x=df['Year'],y = df['narcotics'],mode='lines',name='out of vehicle theft')
fig.add_scatter(x=df['Year'],y = df['burglary'],mode='lines',name='out of vehicle theft')
fig.add_scatter(x=df['Year'],y = df['drunk.driving'],mode='lines',name='out of vehicle theft')
fig.add_scatter(x=df['Year'],y = df['assault'],mode='lines',name='out of vehicle theft')

fig.show()
# Out:
# <div>
#
#
#             <div id="6ff3724c-4dcd-49d4-8f44-c25f1858980f" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("6ff3724c-4dcd-49d4-8f44-c25f1858980f")) {
#                     Plotly.newPlot(
#                         '6ff3724c-4dcd-49d4-8f44-c25f1858980f',
# ...
